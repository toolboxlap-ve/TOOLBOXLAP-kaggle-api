# %% [markdown]
# # TOOLBOXLAP — Kaggle Hugging Face / Ollama / ngrok API\n\nEnable a **GPU** accelerator and **Internet** in Kaggle notebook settings, then run the next cell. It launches the tested TOOLBOXLAP V6 baseline, prints a temporary OpenAI-compatible ngrok URL, and ends with `EVERYTHING IS WORKING` after its public API test.\n\nWebsite: https://toolboxlap.com  |  YouTube: https://www.youtube.com/@TOOLBOXLAP-u1c

# %%
# This notebook intentionally downloads the versioned launcher from this repository.\n# Never paste tokens into this source; the launcher asks for the ngrok authtoken at runtime.\n!curl -fsSL https://raw.githubusercontent.com/toolboxlap-ve/TOOLBOXLAP-kaggle-api/main/scripts/toolboxlap_kaggle_hf_ollama_ngrok.py -o toolboxlap_kaggle_hf_ollama_ngrok.py\n!python toolboxlap_kaggle_hf_ollama_ngrok.py
